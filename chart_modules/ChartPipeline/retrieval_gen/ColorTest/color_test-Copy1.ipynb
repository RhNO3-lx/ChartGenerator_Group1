# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def display_colors(color_list, bcg_color):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 4))
    
    n_colors = len(color_list)
    for i, color in enumerate(color_list):
        rect = patches.Rectangle((i, 0), 1, 1, facecolor=color)
        ax1.add_patch(rect)
    
    ax1.set_xlim(-0.1, n_colors + 0.1)
    ax1.set_ylim(-0.1, 1.1)
    ax1.axis('equal')
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax1.set_title('Color List')

    rect = patches.Rectangle((0, 0), 1, 1, facecolor=bcg_color)
    ax2.add_patch(rect)

    ax2.set_xlim(-0.1, 1.1)
    ax2.set_ylim(-0.1, 1.1)
    ax2.axis('equal')
    ax2.set_xticks([])
    ax2.set_yticks([])
    ax2.set_title('Background Color')
    
    plt.tight_layout()
    plt.show()

# color_data = {
#     'color_list': ['#A27657', '#D5926A', '#E26377', '#55AE2B', '#14424B'],
#     'bcg': '#00137F'
# }

# display_colors(color_data['color_list'], color_data['bcg'])

# %%
# color_data = get_palette(7, True, image_path)
color_data = {'color_list': ['#A27657',
  '#D5926A',
  '#E26377',
  '#59B62E',
  '#14424B',
  '#762770',
  '#DC253E'],
 'bcg': '#00137F'}
# display_colors(color_data['color_list'], color_data['bcg'])

# %%
from color_template import ColorDesign
color_design1 = ColorDesign(color_data, mode='monochromatic')
bcg_color = color_design1.get_color('background', 1)[0]
# single color mode
# seed_color = 0 the farthest color, 1 counter color(white/black), ... other random color in palette
# seed_text = 0 all same, 1 all black/white, 2 extend in l, 3 main color and other black/white, reverse: inside color
# seed_mark = 0 all same, 1-4 different extend, 5 gray

for seed in range(4):
    text_colors = color_design1.get_color('text', 8, seed_color=0, seed_text=seed)

for seed in range(6):
    text_colors = color_design1.get_color('marks', 8, seed_color=0, seed_mark=seed)
