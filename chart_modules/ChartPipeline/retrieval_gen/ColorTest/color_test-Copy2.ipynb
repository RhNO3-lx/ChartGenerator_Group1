# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def display_colors(color_list, bcg_color):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 4))
    
    n_colors = len(color_list)
    for i, color in enumerate(color_list):
        rect = patches.Rectangle((i, 0), 1, 1, facecolor=color)
        ax1.add_patch(rect)
    
    ax1.set_xlim(-0.1, n_colors + 0.1)
    ax1.set_ylim(-0.1, 1.1)
    ax1.axis('equal')
    ax1.set_xticks([])
    ax1.set_yticks([])
    ax1.set_title('Color List')

    rect = patches.Rectangle((0, 0), 1, 1, facecolor=bcg_color)
    ax2.add_patch(rect)

    ax2.set_xlim(-0.1, 1.1)
    ax2.set_ylim(-0.1, 1.1)
    ax2.axis('equal')
    ax2.set_xticks([])
    ax2.set_yticks([])
    ax2.set_title('Background Color')
    
    plt.tight_layout()
    plt.show()

# color_data = {
#     'color_list': ['#A27657', '#D5926A', '#E26377', '#55AE2B', '#14424B'],
#     'bcg': '#00137F'
# }

# display_colors(color_data['color_list'], color_data['bcg'])

# %%
# color_data = get_palette(7, True, image_path)
color_data =  {'color_list': ['#2F877A', '#239C96', '#2E3742', '#F6F6F6', '#296169', '#3DD8D3', '#A6B2A7'], 'bcg': '#0E325A'}
# # colors:  {'group1': ['#7c6563'], 'group2': ['#7c6563']}
# display_colors(color_data['color_list'], color_data['bcg'])

# %%
from color_template import ColorDesign
color_design1 = ColorDesign(color_data, mode='complementary') # polychromatic
# color_design1 = ColorDesign(color_data, mode='polychromatic') # polychromatic
bcg_color = color_design1.get_color('background', 1)[0]

display_colors(color_design1.hex_rgb_pool, color_data['bcg'])
text_colors = color_design1.get_color('marks', number = 1, group = 2, seed_mark=1)
display_colors(text_colors['group1'] + text_colors['group2'], bcg_color)
# Out:
# rgb_pool [(47, 135, 122), (46, 55, 66), (246, 246, 246), (41, 97, 105), (61, 216, 211), (166, 178, 167)]
# complementary [((61, 216, 211), [255, 165, 180])]
# dark
